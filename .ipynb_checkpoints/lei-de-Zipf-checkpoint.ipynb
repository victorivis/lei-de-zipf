# %%
def wordCount(x=1):
    if x == 1:
        x = input("Arquivo a ser lido: ")
        
    import string
    
    leitor = open("livros/{}".format(x), "r", encoding="utf-8")
    texto = leitor.read()
    # print(texto)
    leitor.close()
    dict = {};
    
    #indica caracteres que serão retirados do livro
    caracteresExcluidos = string.punctuation + "'-1234567890"+'"'+"»*”“\n"
    
    #Em alice o caractere especial ’ (não é a aspa do teclado) pode mudar os resultados
    
    #percorre cada caractere de carateresExcluidos e retira eles do texto original
    for letra in caracteresExcluidos:
      texto = texto.replace(letra, ' ')
    
    texto = texto.casefold()
    array = texto.split()
    
    #conta as palavras
    for string in array:
    	if string in dict:
    		dict[string] += 1;
    	else:
    		dict[string] = 1;
    
    #ordena a lista pela frequencia
    dict = sorted(dict.items(), key=lambda x:x[1], reverse=True)
    
    for j in dict:
        print(j)
    
    saida = open("resultados/saida-{}".format(x), "w", encoding="utf-8");
    for i in dict:
    	saida.write("{}\n".format(i))
    saida.close()

wordCount("critao.txt")
# Out:
# 1
# ('que', 228)
# ('a', 183)
# ('de', 159)
# ('não', 139)
# ('e', 137)
# ('se', 97)
# ('o', 88)
# ('sócrates', 81)
# ('critão', 69)
# ('te', 61)
# ('é', 59)
# ('ou', 50)
# ('para', 50)
# ('com', 48)
# ('os', 47)
# ('em', 43)
# ('mais', 41)
# ('as', 39)
# ('do', 38)
# ('nos', 37)
# ('ao', 35)
# ('nós', 35)
# ('como', 33)
# ('nem', 32)
# ('por', 31)
# ('mas', 30)
# ('me', 28)
# ('assim', 24)
# ('uma', 23)
# ('leis', 22)
# ('dos', 21)
# ('bem', 20)
# ('da', 19)
# ('no', 19)
# ('teu', 17)
# ('cidade', 17)
# ('eu', 16)
# ('deve', 16)
# ('na', 16)
# ('das', 16)
# ('isso', 16)
# ('injustiça', 16)
# ('teus', 15)
# ('um', 15)
# ('tu', 15)
# ('outros', 14)
# ('fazer', 14)
# ('porque', 13)
# ('todos', 13)
# ('ser', 13)
# ('pois', 13)
# ('sem', 13)
# ('justiça', 13)
# ('agora', 12)
# ('será', 12)
# ('à', 12)
# ('tua', 12)
# ('devemos', 12)
# ('então', 11)
# ('mesmo', 11)
# ('porém', 11)
# ('viver', 11)
# ('daqui', 11)
# ('quem', 11)
# ('multidão', 11)
# ('ainda', 10)
# ('mal', 10)
# ('também', 10)
# ('ti', 10)
# ('meu', 10)
# ('outra', 10)
# ('outras', 10)
# ('algum', 9)
# ('ter', 9)
# ('tempo', 8)
# ('quanto', 8)
# ('nossa', 8)
# ('morrer', 8)
# ('amigos', 8)
# ('acho', 8)
# ('lá', 8)
# ('menos', 8)
# ('tudo', 8)
# ('opinião', 8)
# ('eles', 8)
# ('contra', 8)
# ('justo', 8)
# ('quando', 8)
# ('razão', 8)
# ('sim', 8)
# ('tanto', 7)
# ('muito', 7)
# ('aos', 7)
# ('às', 7)
# ('demais', 7)
# ('parte', 7)
# ('qualquer', 7)
# ('onde', 7)
# ('qual', 7)
# ('essa', 7)
# ('injusto', 7)
# ('quer', 7)
# ('querido', 2)
# ('examinar', 2)
# ('razões', 2)
# ('posso', 2)
# ('vista', 2)
# ('fica', 2)
# ('crianças', 2)
# ('bens', 2)
# ('exame', 2)
# ('primeiro', 2)
# ('alegas', 2)
# ('acatar', 2)
# ('era', 2)
# ('creio', 2)
# ('próprio', 2)
# ('acatamento', 2)
# ('norma', 2)
# ('vias', 2)
# ('ruins', 2)
# ('tais', 2)
# ('somente', 2)
# ('porventura', 2)
# ('temer', 2)
# ('evidentemente', 2)
# ('entendido', 2)
# ('àquele', 2)
# ('conseqüência', 2)
# ('ruim', 2)
# ('vendo', 2)
# ('arruina', 2)
# ('belo', 2)
# ('deliberação', 2)
# ('seguir', 2)
# ('melhora', 2)
# ('regime', 2)
# ('podemos', 2)
# ('arruinar', 2)
# ('autoridade', 2)
# ('matéria', 2)
# ('única', 2)
# ('apontas', 2)
# ('caminho', 2)
# ('pensamento', 2)
# ('haverá', 2)
# ('acabamos', 2)
# ('pé', 2)
# ('importância', 2)
# ('honra', 2)
# ('conforme', 2)
# ('desses', 2)
# ('princípios', 2)
# ('provar', 2)
# ('dizíamos', 2)
# ('vão', 2)
# ('acerto', 2)
# ('argumentos', 2)
# ('poucos', 2)
# ('somos', 2)
# ('demos', 2)
# ('fazem', 2)
# ('pessoa', 2)
# ('suma', 2)
# ('sei', 2)
# ('tens', 2)
# ('conhecer', 2)
# ('cumprida', 2)
# ('lesar', 2)
# ('pretendes', 2)
# ('intentas', 2)
# ('medida', 2)
# ('força', 2)
# ('proferidas', 2)
# ('essas', 2)
# ('responderei', 2)
# ('direi', 2)
# ('quê', 2)
# ('ás', 2)
# ('pergunta', 2)
# ('dentre', 2)
# ('regulam', 2)
# ('diria', 2)
# ('filho', 2)
# ('fizeram', 2)
# ('ascendentes', 2)
# ('julgas', 2)
# ('terias', 2)
# ('amo', 2)
# ('tivesse', 2)
# ('doesto', 2)
# ('golpe', 2)
# ('obediência', 2)
# ('cumprir', 2)
# ('guerra', 2)
# ('ordens', 2)
# ('obter', 2)
# ('geramos', 2)
# ('cidadãos', 2)
# ('facultado', 2)
# ('agrado', 2)
# ('vós', 2)
# ('fato', 2)
# ('obedecer', 2)
# ('persuadir', 2)
# ('nela', 2)
# ('preferias', 2)
# ('agradava', 2)
# ('exílio', 2)
# ('obrigaste', 2)
# ('deveres', 2)
# ('cidadão', 2)
# ('serem', 2)
# ('benefício', 2)
# ('entrarás', 2)
# ('viveres', 2)
# ('oh', 2)
# ('formação', 2)
# ('cuidarão', 2)
# ('hão', 2)
# ('dano', 2)
# ('ouvindo', 2)
# ('viestes', 1)
# ('estas', 1)
# ('madrugada', 1)
# ('precisamente', 1)
# ('começa', 1)
# ('clarear', 1)
# ('admira', 1)
# ('guarda', 1)
# ('haja', 1)
# ('atendido', 1)
# ('acostumou', 1)
# ('freqüentar', 1)
# ('ademais', 1)
# ('favores', 1)
# ('acabas', 1)
# ('acordaste', 1)
# ('sentaste', 1)
# ('calado', 1)
# ('gostaria', 1)
# ('passar', 1)
# ('levá', 1)
# ('torná', 1)
# ('devendo', 1)
# ('estando', 1)
# ('vivo', 1)
# ('criados', 1)
# ('companhia', 1)
# ('cuidar', 1)
# ('deveras', 1)
# ('protestam', 1)
# ('hás', 1)
# ('admitir', 1)
# ('ouve', 1)
# ('sobreponhas', 1)
# ('justificações', 1)
# ('perante', 1)
# ('governam', 1)
# ('aquele', 1)
# ('pio', 1)
# ('tiveres', 1)
# ('presentemente', 1)
# ('partirás', 1)
# ('vítima', 1)
# ('evades', 1)
# ('retribuindo', 1)
# ('vergonhosamente', 1)
# ('logrando', 1)
# ('próprios', 1)
# ('detrimento', 1)
# ('devias', 1)
# ('enquanto', 1)
# ('estaremos', 1)
# ('indignadas', 1)
# ('embaixo', 1)
# ('irmãs', 1)
# ('acolher', 1)
# ('benevolência', 1)
# ('sabedoras', 1)
# ('procuraste', 1)
# ('recriminação', 1)
# ('companheiro', 1)
# ('coribantes', 1)
# ('som', 1)
# ('flautas', 1)
# ('ressonância', 1)
# ('dessas', 1)
# ('zumbe', 1)
# ('íntimo', 1)
# ('deixa', 1)
# ('outrem', 1)
# ('acredita', 1)
# ('disseres', 1)
# ('diverso', 1)
# ('di', 1)
# ('esperas', 1)
# ('resultado', 1)
# ('desistem', 1)
# ('procedamos', 1)
# ('daquela', 1)
# ('divindade', 1)
# ('guia', 1)

# %%
#exemplo de grafico de pontos
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
#grafico de barras
import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.bar(x,y)
plt.show()

# %%
# Essa parte sao algumas anotacoes talvez nao concluidas
# abaixo eu vou tentar fazer a distribuicao, mas ao inves de agrupar um por vez
# vao ser agrupados em pares e em trios
def wordCountPar(x=1):
    import string
    if x == 1:
        x = input("Arquivo a ser lido: ")
        
    leitor = open("livros/{}".format(x), "r", encoding="utf-8")
    texto = leitor.read()
    leitor.close()
    dict = {}
    
    caracteresExcluidos = string.punctuation + "'-1234567890" + '"' + "»*”“"
    
    for letra in caracteresExcluidos:
        texto = texto.replace(letra, ' ')
    
    texto = texto.casefold()
    array = texto.split()
    contador = 1
    
    while contador < len(array):
        string = array[contador - 1] + " " + array[contador]
        if string in dict:
            dict[string] = dict[string] + 1
        else:
            dict[string] = 1
        contador += 1
    
    #ordena a lista pela frequencia
    dict = sorted(dict.items(), key=lambda x:x[1], reverse=True)

    # retiro o comentario para ver a saida completa
    # for j in dict:
    #     print(j)
    
    saida = open("resultados-pares/saida-{}".format(x), "w", encoding="utf-8");
    for i in dict:
    	saida.write("{}\n".format(i))
    saida.close()
    print("arquivo saida-{} criado na pasta resultados-pares".format(x))

wordCountPar("critao.txt")
# Out:
# arquivo saida-critao.txt criado na pasta resultados-pares

# %%
#codigo para agrupar em trios

def wordCountPar(x=1):
    import string
    if x == 1:
        x = input("Arquivo a ser lido: ")
        
    leitor = open("livros/{}".format(x), "r", encoding="utf-8")
    texto = leitor.read()
    leitor.close()
    dict = {}
    
    caracteresExcluidos = string.punctuation + "'-1234567890" + '"' + "»*”“"
    
    for letra in caracteresExcluidos:
        texto = texto.replace(letra, ' ')
    
    texto = texto.casefold()
    array = texto.split()
    contador = 2
    
    while contador < len(array):
        string = array[contador - 2] + " " + array[contador-1] + " " + array[contador]
        if string in dict:
            dict[string] = dict[string] + 1
        else:
            dict[string] = 1
        contador += 1
    
    #ordena a lista pela frequencia
    dict = sorted(dict.items(), key=lambda x:x[1], reverse=True)

    # retiro o comentario para ver a saida completa
    # for j in dict:
    #     print(j)
    
    saida = open("resultados-trios/saida-{}".format(x), "w", encoding="utf-8");
    for i in dict:
    	saida.write("{}\n".format(i))
    saida.close()
    print("arquivo saida-{} criado na pasta resultados-trios".format(x))

wordCountPar("critao.txt")
# Out:
# arquivo saida-critao.txt criado na pasta resultados-trios

# %%
import math
from scipy.special import gamma, digamma

constEuler = 0.57721566490153286060651209008240243

def fat(n):
    total = 1
    for i in range(n):
        total *= (i + 1)
    return total
        
def porcZipf(n, rank=1):
    if n > 0:
        total = 0
        for j in range(1, n+1):
            total += 1/j
        return 1/(total*rank)
    else:
        print("Calculo impossivel")

# A aproximacao parece ruim
for i in range(10000, 10004):
    aprox = 1
    if i!=1:
        aprox = 100/(constEuler*math.log(i))
    print("Quantidade de elementos {:5d} - porcentagem: {:2.2f}% - aproximacao: {:.2f}%".format(i, 100 * porcZipf(i, 1), aprox))
# Out:
# Quantidade de elementos 10000 - porcentagem: 10.22% - aproximacao: 18.81%
# Quantidade de elementos 10001 - porcentagem: 10.22% - aproximacao: 18.81%
# Quantidade de elementos 10002 - porcentagem: 10.22% - aproximacao: 18.81%
# Quantidade de elementos 10003 - porcentagem: 10.22% - aproximacao: 18.81%

# %%
import numpy as np

# arredondar para cima
from math import ceil

def receberDict(x=1):
    if x==1:
        x=input("Arquivo a ser lido: ")
    leitor = open("{}".format(x), "r", encoding="utf-8")
    texto = leitor.read()
    for letra in "(),":
        texto = texto.replace(letra, " ")
    texto = texto.split()

    dict = {}
    for i in range(0, len(texto), 2):
        chave = texto[i].strip("'")
        valor = int(texto[i + 1])
        dict[chave] = valor
    return dict

dicionario = receberDict("resultados/saida-alice.txt")
listaValores = list(dicionario.values())
listaChaves = list(dicionario.keys())

totalDePalavras = ceil(sum(listaValores))

for i in range(1, len(listaValores)):
    print("Valor esperado: {:.0f}".format(ceil(porcZipf(totalDePalavras, i)*totalDePalavras)))
    print("Valor real: ", listaValores[i-1], "\n")
# Out:
# Valor esperado: 2735
# Valor real:  1828
#
# Valor esperado: 1368
# Valor real:  918
#
# Valor esperado: 912
# Valor real:  806
#
# Valor esperado: 684
# Valor real:  690
#
# Valor esperado: 547
# Valor real:  634
#
# Valor esperado: 456
# Valor real:  538
#
# Valor esperado: 391
# Valor real:  538
#
# Valor esperado: 342
# Valor real:  459
#
# Valor esperado: 304
# Valor real:  434

# %% [markdown]
# ### Definição formal
#
# f(k; N)
# $\frac{1}{2}$\]s grandes.

# %%
import matplotlib.pyplot as plt
import numpy as np

def distribuicao_zipf(n, y=1, a=2.7):
    # Gera os ranks e probabilidades de acordo com a lei de Zipf
    ranks = np.arange(1+a, n+1+a)
    probabilities = 1 / (ranks**y)

    # Normaliza as probabilidades para que somem 1
    probabilities /= np.sum(probabilities)

    return ranks, probabilities

def plot_zipf_distribution(n, y):
    ranks, probabilities = distribuicao_zipf(n, y)

    # Cria o gráfico
    plt.figure(figsize=(10, 6))
    plt.plot(ranks, probabilities, color='blue', alpha=0.7)
    plt.xscale('log')
    plt.yscale('log')
    plt.title(f'Distribuição de Zipf para n={n} e y={y}')
    plt.xlabel('Rank')
    plt.ylabel('Probabilidade')
    plt.show()
    print("ranks: ", ranks, "\nprobalidades: ", probabilities)

# Exemplo de uso
n_palavras_diferentes = 100
parametro_y = 1
plot_zipf_distribution(n_palavras_diferentes, parametro_y)
# Out:
# ranks:  [  3.7   4.7   5.7   6.7   7.7   8.7   9.7  10.7  11.7  12.7  13.7  14.7
#   15.7  16.7  17.7  18.7  19.7  20.7  21.7  22.7  23.7  24.7  25.7  26.7
#   27.7  28.7  29.7  30.7  31.7  32.7  33.7  34.7  35.7  36.7  37.7  38.7
#   39.7  40.7  41.7  42.7  43.7  44.7  45.7  46.7  47.7  48.7  49.7  50.7
#   51.7  52.7  53.7  54.7  55.7  56.7  57.7  58.7  59.7  60.7  61.7  62.7
#   63.7  64.7  65.7  66.7  67.7  68.7  69.7  70.7  71.7  72.7  73.7  74.7
#   75.7  76.7  77.7  78.7  79.7  80.7  81.7  82.7  83.7  84.7  85.7  86.7
#   87.7  88.7  89.7  90.7  91.7  92.7  93.7  94.7  95.7  96.7  97.7  98.7
#   99.7 100.7 101.7 102.7]
# probalidades:  [0.07789848 0.06132433 0.05056568 0.04301856 0.03743174 0.03312924
#  0.02971385 0.02693686 0.02463456 0.02269483 0.02103828 0.0196071
#  0.01835824 0.01725894 0.01628386 0.01541307 0.01463068 0.01392388
#  0.01328223 0.01269711 0.01216137 0.011669   0.01121496 0.01079492
#  0.01040521 0.01004266 0.00970452 0.00938842 0.00909225 0.0088142
#  0.00855265 0.00830618 0.00807351 0.00785353 0.00764521 0.00744766
#  0.00726006 0.00708168 0.00691186 0.00674999 0.00659552 0.00644797
#  0.00630688 0.00617183 0.00604244 0.00591836 0.00579928 0.0056849
#  0.00557494 0.00546915 0.00536731 0.00526918 0.00517458 0.00508332
#  0.00499522 0.00491013 0.00482788 0.00474834 0.00467138 0.00459688
#  0.00452472 0.00445478 0.00438698 0.0043212  0.00425738 0.00419541
#  0.00413521 0.00407672 0.00401987 0.00396457 0.00391078 0.00385843
#  0.00380746 0.00375781 0.00370945 0.00366232 0.00361637 0.00357155
#  0.00352784 0.00348518 0.00344354 0.00340289 0.00336318 0.00332439
#  0.00328648 0.00324943 0.0032132  0.00317778 0.00314312 0.00310922
#  0.00307603 0.00304355 0.00301175 0.0029806  0.0029501  0.00292021
#  0.00289092 0.00286221 0.00283406 0.00280647]
