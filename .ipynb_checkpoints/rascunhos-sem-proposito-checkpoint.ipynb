# %%
import math
from scipy.special import gamma, digamma

constEuler = 0.57721566490153286060651209008240243

def fat(n):
    total = 1
    for i in range(n):
        total *= (i + 1)
    return total
        
def porcZipf(n, rank=1):
    if n > 0:
        total = 0
        for j in range(1, n+1):
            total += 1/j
        return 1/(total*rank)
    else:
        print("Calculo impossivel")

# A aproximacao parece ruim
for i in range(1, 171):
    aprox = 1
    if i!=1:
        aprox = 100/(constEuler*math.log(i))
    print("Quantidade de elementos {:5d} - porcentagem: {:2.2f}% - aproximacao: {:.2f}%".format(i, 100 * porcZipf(i, 1), aprox))
# Out:
# Quantidade de elementos     1 - porcentagem: 100.00% - aproximacao: 1.00%
# Quantidade de elementos     2 - porcentagem: 66.67% - aproximacao: 249.94%
# Quantidade de elementos     3 - porcentagem: 54.55% - aproximacao: 157.69%
# Quantidade de elementos     4 - porcentagem: 48.00% - aproximacao: 124.97%
# Quantidade de elementos     5 - porcentagem: 43.80% - aproximacao: 107.64%
# Quantidade de elementos     6 - porcentagem: 40.82% - aproximacao: 96.69%
# Quantidade de elementos     7 - porcentagem: 38.57% - aproximacao: 89.03%
# Quantidade de elementos     8 - porcentagem: 36.79% - aproximacao: 83.31%
# Quantidade de elementos     9 - porcentagem: 35.35% - aproximacao: 78.85%
# Quantidade de elementos    10 - porcentagem: 34.14% - aproximacao: 75.24%
# Quantidade de elementos    11 - porcentagem: 33.11% - aproximacao: 72.25%
# Quantidade de elementos    12 - porcentagem: 32.22% - aproximacao: 69.72%
# Quantidade de elementos    13 - porcentagem: 31.45% - aproximacao: 67.54%
# Quantidade de elementos    14 - porcentagem: 30.75% - aproximacao: 65.65%
# Quantidade de elementos    15 - porcentagem: 30.14% - aproximacao: 63.97%
# Quantidade de elementos    16 - porcentagem: 29.58% - aproximacao: 62.49%
# Quantidade de elementos    17 - porcentagem: 29.07% - aproximacao: 61.15%
# Quantidade de elementos    18 - porcentagem: 28.61% - aproximacao: 59.94%
# Quantidade de elementos    19 - porcentagem: 28.19% - aproximacao: 58.84%
# Quantidade de elementos    20 - porcentagem: 27.80% - aproximacao: 57.83%
# Quantidade de elementos    21 - porcentagem: 27.43% - aproximacao: 56.90%
# Quantidade de elementos    22 - porcentagem: 27.09% - aproximacao: 56.05%
# Quantidade de elementos    23 - porcentagem: 26.78% - aproximacao: 55.25%
# Quantidade de elementos    24 - porcentagem: 26.48% - aproximacao: 54.51%
# Quantidade de elementos    25 - porcentagem: 26.21% - aproximacao: 53.82%
# Quantidade de elementos    26 - porcentagem: 25.94% - aproximacao: 53.17%
# Quantidade de elementos    27 - porcentagem: 25.70% - aproximacao: 52.56%
# Quantidade de elementos    28 - porcentagem: 25.46% - aproximacao: 51.99%
# Quantidade de elementos    29 - porcentagem: 25.24% - aproximacao: 51.45%
# Quantidade de elementos    30 - porcentagem: 25.03% - aproximacao: 50.94%
# Quantidade de elementos    31 - porcentagem: 24.83% - aproximacao: 50.45%
# Quantidade de elementos    32 - porcentagem: 24.64% - aproximacao: 49.99%
# Quantidade de elementos    33 - porcentagem: 24.46% - aproximacao: 49.55%
# Quantidade de elementos    34 - porcentagem: 24.28% - aproximacao: 49.13%
# Quantidade de elementos    35 - porcentagem: 24.12% - aproximacao: 48.73%
# Quantidade de elementos    36 - porcentagem: 23.95% - aproximacao: 48.35%
# Quantidade de elementos    37 - porcentagem: 23.80% - aproximacao: 47.98%
# Quantidade de elementos    38 - porcentagem: 23.65% - aproximacao: 47.63%
# Quantidade de elementos    39 - porcentagem: 23.51% - aproximacao: 47.29%
# Quantidade de elementos    40 - porcentagem: 23.37% - aproximacao: 46.96%
# Quantidade de elementos    41 - porcentagem: 23.24% - aproximacao: 46.65%
# Quantidade de elementos    42 - porcentagem: 23.11% - aproximacao: 46.35%
# Quantidade de elementos    43 - porcentagem: 22.99% - aproximacao: 46.06%
# Quantidade de elementos    44 - porcentagem: 22.87% - aproximacao: 45.78%
# Quantidade de elementos    45 - porcentagem: 22.75% - aproximacao: 45.51%
# Quantidade de elementos    46 - porcentagem: 22.64% - aproximacao: 45.25%
# Quantidade de elementos    47 - porcentagem: 22.53% - aproximacao: 45.00%
# Quantidade de elementos    48 - porcentagem: 22.43% - aproximacao: 44.75%
# Quantidade de elementos    49 - porcentagem: 22.33% - aproximacao: 44.52%
# Quantidade de elementos    50 - porcentagem: 22.23% - aproximacao: 44.29%
# Quantidade de elementos    51 - porcentagem: 22.13% - aproximacao: 44.06%
# Quantidade de elementos    52 - porcentagem: 22.04% - aproximacao: 43.85%
# Quantidade de elementos    53 - porcentagem: 21.94% - aproximacao: 43.64%
# Quantidade de elementos    54 - porcentagem: 21.86% - aproximacao: 43.43%
# Quantidade de elementos    55 - porcentagem: 21.77% - aproximacao: 43.23%
# Quantidade de elementos    56 - porcentagem: 21.69% - aproximacao: 43.04%
# Quantidade de elementos    57 - porcentagem: 21.60% - aproximacao: 42.85%
# Quantidade de elementos    58 - porcentagem: 21.52% - aproximacao: 42.67%
# Quantidade de elementos    59 - porcentagem: 21.44% - aproximacao: 42.49%
# Quantidade de elementos    60 - porcentagem: 21.37% - aproximacao: 42.31%
# Quantidade de elementos    61 - porcentagem: 21.29% - aproximacao: 42.14%
# Quantidade de elementos    62 - porcentagem: 21.22% - aproximacao: 41.98%
# Quantidade de elementos    63 - porcentagem: 21.15% - aproximacao: 41.82%
# Quantidade de elementos    64 - porcentagem: 21.08% - aproximacao: 41.66%
# Quantidade de elementos    65 - porcentagem: 21.01% - aproximacao: 41.50%
# Quantidade de elementos    66 - porcentagem: 20.94% - aproximacao: 41.35%
# Quantidade de elementos    67 - porcentagem: 20.88% - aproximacao: 41.20%
# Quantidade de elementos    68 - porcentagem: 20.82% - aproximacao: 41.06%
# Quantidade de elementos    69 - porcentagem: 20.75% - aproximacao: 40.92%
# Quantidade de elementos    70 - porcentagem: 20.69% - aproximacao: 40.78%
# Quantidade de elementos    71 - porcentagem: 20.63% - aproximacao: 40.64%
# Quantidade de elementos    72 - porcentagem: 20.57% - aproximacao: 40.51%
# Quantidade de elementos    73 - porcentagem: 20.51% - aproximacao: 40.38%
# Quantidade de elementos    74 - porcentagem: 20.46% - aproximacao: 40.25%
# Quantidade de elementos    75 - porcentagem: 20.40% - aproximacao: 40.13%
# Quantidade de elementos    76 - porcentagem: 20.35% - aproximacao: 40.00%
# Quantidade de elementos    77 - porcentagem: 20.29% - aproximacao: 39.88%
# Quantidade de elementos    78 - porcentagem: 20.24% - aproximacao: 39.77%
# Quantidade de elementos    79 - porcentagem: 20.19% - aproximacao: 39.65%
# Quantidade de elementos    80 - porcentagem: 20.14% - aproximacao: 39.54%
# Quantidade de elementos    81 - porcentagem: 20.09% - aproximacao: 39.42%
# Quantidade de elementos    82 - porcentagem: 20.04% - aproximacao: 39.31%
# Quantidade de elementos    83 - porcentagem: 19.99% - aproximacao: 39.21%
# Quantidade de elementos    84 - porcentagem: 19.94% - aproximacao: 39.10%
# Quantidade de elementos    85 - porcentagem: 19.90% - aproximacao: 39.00%
# Quantidade de elementos    86 - porcentagem: 19.85% - aproximacao: 38.89%
# Quantidade de elementos    87 - porcentagem: 19.81% - aproximacao: 38.79%
# Quantidade de elementos    88 - porcentagem: 19.76% - aproximacao: 38.69%
# Quantidade de elementos    89 - porcentagem: 19.72% - aproximacao: 38.60%
# Quantidade de elementos    90 - porcentagem: 19.68% - aproximacao: 38.50%
# Quantidade de elementos    91 - porcentagem: 19.63% - aproximacao: 38.41%
# Quantidade de elementos    92 - porcentagem: 19.59% - aproximacao: 38.31%
# Quantidade de elementos    93 - porcentagem: 19.55% - aproximacao: 38.22%
# Quantidade de elementos    94 - porcentagem: 19.51% - aproximacao: 38.13%
# Quantidade de elementos    95 - porcentagem: 19.47% - aproximacao: 38.04%
# Quantidade de elementos    96 - porcentagem: 19.43% - aproximacao: 37.96%
# Quantidade de elementos    97 - porcentagem: 19.39% - aproximacao: 37.87%
# Quantidade de elementos    98 - porcentagem: 19.35% - aproximacao: 37.79%
# Quantidade de elementos    99 - porcentagem: 19.31% - aproximacao: 37.70%
# Quantidade de elementos   100 - porcentagem: 19.28% - aproximacao: 37.62%
# Quantidade de elementos   101 - porcentagem: 19.24% - aproximacao: 37.54%
# Quantidade de elementos   102 - porcentagem: 19.20% - aproximacao: 37.46%
# Quantidade de elementos   103 - porcentagem: 19.17% - aproximacao: 37.38%
# Quantidade de elementos   104 - porcentagem: 19.13% - aproximacao: 37.30%
# Quantidade de elementos   105 - porcentagem: 19.10% - aproximacao: 37.23%
# Quantidade de elementos   106 - porcentagem: 19.06% - aproximacao: 37.15%
# Quantidade de elementos   107 - porcentagem: 19.03% - aproximacao: 37.08%
# Quantidade de elementos   108 - porcentagem: 19.00% - aproximacao: 37.00%
# Quantidade de elementos   109 - porcentagem: 18.96% - aproximacao: 36.93%
# Quantidade de elementos   110 - porcentagem: 18.93% - aproximacao: 36.86%
# Quantidade de elementos   111 - porcentagem: 18.90% - aproximacao: 36.79%
# Quantidade de elementos   112 - porcentagem: 18.87% - aproximacao: 36.72%
# Quantidade de elementos   113 - porcentagem: 18.84% - aproximacao: 36.65%
# Quantidade de elementos   114 - porcentagem: 18.80% - aproximacao: 36.58%
# Quantidade de elementos   115 - porcentagem: 18.77% - aproximacao: 36.51%
# Quantidade de elementos   116 - porcentagem: 18.74% - aproximacao: 36.45%
# Quantidade de elementos   117 - porcentagem: 18.71% - aproximacao: 36.38%
# Quantidade de elementos   118 - porcentagem: 18.68% - aproximacao: 36.31%
# Quantidade de elementos   119 - porcentagem: 18.65% - aproximacao: 36.25%
# Quantidade de elementos   120 - porcentagem: 18.63% - aproximacao: 36.19%
# Quantidade de elementos   121 - porcentagem: 18.60% - aproximacao: 36.12%
# Quantidade de elementos   122 - porcentagem: 18.57% - aproximacao: 36.06%
# Quantidade de elementos   123 - porcentagem: 18.54% - aproximacao: 36.00%
# Quantidade de elementos   124 - porcentagem: 18.51% - aproximacao: 35.94%
# Quantidade de elementos   125 - porcentagem: 18.49% - aproximacao: 35.88%
# Quantidade de elementos   126 - porcentagem: 18.46% - aproximacao: 35.82%
# Quantidade de elementos   127 - porcentagem: 18.43% - aproximacao: 35.76%
# Quantidade de elementos   128 - porcentagem: 18.41% - aproximacao: 35.71%
# Quantidade de elementos   129 - porcentagem: 18.38% - aproximacao: 35.65%
# Quantidade de elementos   130 - porcentagem: 18.35% - aproximacao: 35.59%
# Quantidade de elementos   131 - porcentagem: 18.33% - aproximacao: 35.54%
# Quantidade de elementos   132 - porcentagem: 18.30% - aproximacao: 35.48%
# Quantidade de elementos   133 - porcentagem: 18.28% - aproximacao: 35.43%
# Quantidade de elementos   134 - porcentagem: 18.25% - aproximacao: 35.37%
# Quantidade de elementos   135 - porcentagem: 18.23% - aproximacao: 35.32%
# Quantidade de elementos   136 - porcentagem: 18.20% - aproximacao: 35.27%
# Quantidade de elementos   137 - porcentagem: 18.18% - aproximacao: 35.21%
# Quantidade de elementos   138 - porcentagem: 18.16% - aproximacao: 35.16%
# Quantidade de elementos   139 - porcentagem: 18.13% - aproximacao: 35.11%
# Quantidade de elementos   140 - porcentagem: 18.11% - aproximacao: 35.06%
# Quantidade de elementos   141 - porcentagem: 18.08% - aproximacao: 35.01%
# Quantidade de elementos   142 - porcentagem: 18.06% - aproximacao: 34.96%
# Quantidade de elementos   143 - porcentagem: 18.04% - aproximacao: 34.91%
# Quantidade de elementos   144 - porcentagem: 18.02% - aproximacao: 34.86%
# Quantidade de elementos   145 - porcentagem: 17.99% - aproximacao: 34.81%
# Quantidade de elementos   146 - porcentagem: 17.97% - aproximacao: 34.76%
# Quantidade de elementos   147 - porcentagem: 17.95% - aproximacao: 34.72%
# Quantidade de elementos   148 - porcentagem: 17.93% - aproximacao: 34.67%
# Quantidade de elementos   149 - porcentagem: 17.91% - aproximacao: 34.62%
# Quantidade de elementos   150 - porcentagem: 17.89% - aproximacao: 34.58%
# Quantidade de elementos   151 - porcentagem: 17.86% - aproximacao: 34.53%
# Quantidade de elementos   152 - porcentagem: 17.84% - aproximacao: 34.48%
# Quantidade de elementos   153 - porcentagem: 17.82% - aproximacao: 34.44%
# Quantidade de elementos   154 - porcentagem: 17.80% - aproximacao: 34.39%
# Quantidade de elementos   155 - porcentagem: 17.78% - aproximacao: 34.35%
# Quantidade de elementos   156 - porcentagem: 17.76% - aproximacao: 34.31%
# Quantidade de elementos   157 - porcentagem: 17.74% - aproximacao: 34.26%
# Quantidade de elementos   158 - porcentagem: 17.72% - aproximacao: 34.22%
# Quantidade de elementos   159 - porcentagem: 17.70% - aproximacao: 34.18%
# Quantidade de elementos   160 - porcentagem: 17.68% - aproximacao: 34.14%
# Quantidade de elementos   161 - porcentagem: 17.66% - aproximacao: 34.09%
# Quantidade de elementos   162 - porcentagem: 17.64% - aproximacao: 34.05%
# Quantidade de elementos   163 - porcentagem: 17.62% - aproximacao: 34.01%
# Quantidade de elementos   164 - porcentagem: 17.61% - aproximacao: 33.97%
# Quantidade de elementos   165 - porcentagem: 17.59% - aproximacao: 33.93%
# Quantidade de elementos   166 - porcentagem: 17.57% - aproximacao: 33.89%
# Quantidade de elementos   167 - porcentagem: 17.55% - aproximacao: 33.85%
# Quantidade de elementos   168 - porcentagem: 17.53% - aproximacao: 33.81%
# Quantidade de elementos   169 - porcentagem: 17.51% - aproximacao: 33.77%
# Quantidade de elementos   170 - porcentagem: 17.49% - aproximacao: 33.73%

# %%
import numpy as np

# arredondar para cima
from math import ceil

def porcZipf(n, rank=1):
    if n > 0:
        total = 0
        for j in range(1, n+1):
            total += 1/j
        return 1/(total*rank)
    else:
        print("Calculo impossivel")

def receberDict(x=1):
    if x==1:
        x=input("Arquivo a ser lido: ")
    leitor = open("{}".format(x), "r", encoding="utf-8")
    texto = leitor.read()
    for letra in "(),":
        texto = texto.replace(letra, " ")
    texto = texto.split()

    dict = {}
    for i in range(0, len(texto), 2):
        chave = texto[i].strip("'")
        valor = int(texto[i + 1])
        dict[chave] = valor
    return dict

dicionario = receberDict("resultados/saida-alice.txt")
listaValores = list(dicionario.values())
listaChaves = list(dicionario.keys())

totalDePalavras = ceil(sum(listaValores))

for i in range(1, 20):
    print("Valor esperado: {:.0f}".format(ceil(porcZipf(totalDePalavras, i)*totalDePalavras)))
    print("Valor real: ", listaValores[i-1], "\n")
# Out:
# Valor esperado: 2735
# Valor real:  1828
#
# Valor esperado: 1368
# Valor real:  918
#
# Valor esperado: 912
# Valor real:  806
#
# Valor esperado: 684
# Valor real:  690
#
# Valor esperado: 547
# Valor real:  634
#
# Valor esperado: 456
# Valor real:  538
#
# Valor esperado: 391
# Valor real:  538
#
# Valor esperado: 342
# Valor real:  459
#
# Valor esperado: 304
# Valor real:  434
#
# Valor esperado: 274
# Valor real:  433
#
# Valor esperado: 249
# Valor real:  395
#
# Valor esperado: 228
# Valor real:  390
#
# Valor esperado: 211
# Valor real:  359
#
# Valor esperado: 196
# Valor real:  292
#
# Valor esperado: 183
# Valor real:  271
#
# Valor esperado: 171
# Valor real:  248
#
# Valor esperado: 161
# Valor real:  227
#
# Valor esperado: 152
# Valor real:  222
#
# Valor esperado: 144
# Valor real:  204

# %%
#Isso o chat gpt fez baseado em algumas citações sobre a lei de zipf eu ainda estou tentando entender como funciona
from scipy.stats import kstest, expon
import numpy as np

def test_zipf_law(word_counts):
    # Sorting words by frequency
    sorted_words = sorted(word_counts, key=word_counts.get, reverse=True)

    # Calculating the frequencies
    frequencies = [word_counts[word] for word in sorted_words]

    # Expected frequencies according to Zipf's law
    expected_frequencies = [frequencies[0] / (i + 1) for i in range(len(frequencies))]

    # Performing the Kolmogorov-Smirnov test with exponential distribution
    ks_statistic, ks_p_value = kstest(frequencies, expon.cdf, args=(0, np.mean(frequencies)))

    # Outputting the results
    print(f"Kolmogorov-Smirnov Statistic: {ks_statistic}")
    print(f"P-Value: {ks_p_value}")

    if ks_p_value < 0.05:
        print("The data does not follow Zipf's law.")
    else:
        print("The data follows Zipf's law.")

# Exemplo de uso
#word_counts = receberDict("resultados/saida-casmurro.txt")
word_counts = {"apple": 10, "banana": 5, "orange": 3, "grape": 2, "pear": 1}
test_zipf_law(word_counts)
# Out:
# Kolmogorov-Smirnov Statistic: 0.211872372254689
# P-Value: 0.9410533364360948
# The data follows Zipf's law.
